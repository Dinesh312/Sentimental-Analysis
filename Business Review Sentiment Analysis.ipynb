# %% [markdown]
# DATA SCRAPING

# %%
import requests
from bs4 import BeautifulSoup

# %%
r = requests.get('https://www.yelp.com/biz/tesla-san-francisco?osq=Tesla+Dealership&start=10')

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
results = soup.findAll(class_='raw__09f24__T4Ezm')

# %%
reviews = []
for res in results[5:]:
    reviews.append(res.text)

# %% [markdown]
# ANALYSIS

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(np.array(reviews), columns = ['review'])

# %%
df['word_count'] = df['review'].apply(lambda x: len(str(x).split(" ")))

# %%
df['char_count'] = df['review'].str.len()

# %%
def avg_word(review):
  words = review.split()
  return (sum(len(word) for word in words) / len(words))
df['avg_word'] = df['review'].apply(lambda x: avg_word(x))

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
df['stopword_count'] = df['review'].apply(lambda x: len([x for x in x.split() if x in stop_words]))

# %%
df
# Out:
#                                                review  word_count  char_count  \
# 0   Today was delivery day and we were pretty exci...         306        1730
# 1   TERRIBLE customer services. The guy name CK in...          90         527
# 2   I recently brought a brand new Tesla to fix so...         156         821
# 3   The service department is horrible in getting ...          73         374
# 4   The service center here is TERRIBLE. I had a t...         267        1424
# 5   The service center here is TERRIBLE. I had a t...         298        1615
# 6   Unfortunately, as a recent new Tesla owner, I ...         184        1079
# 7   My Tesla 2016 model x would be the perfect car...          58         345
# 8   I had an issue with the undercarriage cover. T...          29         164
# 9   We dropped our car at our scheduled appointmen...         125         663
# 10  There is inconsistency of excellent service he...          69         372
#
#     avg_word  stopword_count
# 0   4.656863             133
# 1   4.866667              35
# 2   4.269231              58
# 3   4.125000              32
# 4   4.337079             113
# 5   4.422819             127
# 6   4.864130              74
# 7   4.948276              23
# 8   4.655172              11
# 9   4.312000              55
# 10  4.492537              30

# %% [markdown]
# CLEANING

# %%
df['review_lowercase'] = df['review'].apply(lambda x: " ".join(x.lower() for x in x.split()))

# %%
df['review_nopunctuation'] = df['review_lowercase'].str.replace('[^\w\s]', '')
# Out:
# <ipython-input-14-2ef11e5d3bbd>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['review_nopunctuation'] = df['review_lowercase'].str.replace('[^\w\s]', '')

# %%
df['review_nopunc_nostop'] = df['review_nopunctuation'].apply(lambda x: " ".join(x for x in x.split() if x not in stop_words))

# %%
freq= pd.Series(" ".join(df['review_nopunc_nostop']).split()).value_counts()[:30]

# %%
other_stopwords = ['get', 'us', 'see', 'use', 'didnt', 'said', 'asked', 'day', 'go', 'even', 'ive', 'right', 'left', 'always', 'would', 'told', 'get', 'one', 'ive', 'go', 'even', 'also', 'ever', 'x', 'take', 'let', 'ap', 'say' ]

# %%
df['review_nopunc_nostop_nocommon'] = df['review_nopunc_nostop'].apply(lambda x: "".join(" ".join(x for x in x.split() if x not in other_stopwords)))

# %% [markdown]
# LEMMATIZING

# %%
from textblob import Word

df['cleaned_review'] = df['review_nopunc_nostop_nocommon'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
df['cleaned_review']
# Out:
# 0     today delivery pretty excited collect car arri...
# 1     terrible customer service guy name ck front id...
# 2     recently brought brand new tesla fix post deli...
# 3     service department horrible getting loaner car...
# 4     service center terrible tire needed patched ta...
# 5     service center terrible tire needed patched ta...
# 6     unfortunately recent new tesla owner agree maj...
# 7     tesla 2016 model perfect car ifservice tech kn...
# 8     issue undercarriage cover rep daniel manager r...
# 9     dropped car scheduled appointment 11am basic c...
# 10    inconsistency excellent service super duper ha...
# Name: cleaned_review, dtype: object

# %% [markdown]
# SENTIMENT ANALYSIS

# %%
from textblob import TextBlob
df['polarity'] = df['cleaned_review'].apply(lambda x: TextBlob(x).sentiment[0])

# %%
df['subjectivity'] = df['cleaned_review'].apply(lambda x: TextBlob(x).sentiment[1])
df
# Out:
#                                                review  word_count  char_count  \
# 0   Today was delivery day and we were pretty exci...         306        1730
# 1   TERRIBLE customer services. The guy name CK in...          90         527
# 2   I recently brought a brand new Tesla to fix so...         156         821
# 3   The service department is horrible in getting ...          73         374
# 4   The service center here is TERRIBLE. I had a t...         267        1424
# 5   The service center here is TERRIBLE. I had a t...         298        1615
# 6   Unfortunately, as a recent new Tesla owner, I ...         184        1079
# 7   My Tesla 2016 model x would be the perfect car...          58         345
# 8   I had an issue with the undercarriage cover. T...          29         164
# 9   We dropped our car at our scheduled appointmen...         125         663
# 10  There is inconsistency of excellent service he...          69         372
#
#     avg_word  stopword_count  \
# 0   4.656863             133
# 1   4.866667              35
# 2   4.269231              58
# 3   4.125000              32
# 4   4.337079             113
# 5   4.422819             127
# 6   4.864130              74
# 7   4.948276              23
# 8   4.655172              11
# 9   4.312000              55
# 10  4.492537              30
#
#                                      review_lowercase  \
# 0   today was delivery day and we were pretty exci...
# 1   terrible customer services. the guy name ck in...
# 2   i recently brought a brand new tesla to fix so...
# 3   the service department is horrible in getting ...
# 4   the service center here is terrible. i had a t...
# 5   the service center here is terrible. i had a t...
# 6   unfortunately, as a recent new tesla owner, i ...
# 7   my tesla 2016 model x would be the perfect car...
# 8   i had an issue with the undercarriage cover. t...
# 9   we dropped our car at our scheduled appointmen...
# 10  there is inconsistency of excellent service he...
#
#                                  review_nopunctuation  \
# 0   today was delivery day and we were pretty exci...
# 1   terrible customer services the guy name ck in ...
# 2   i recently brought a brand new tesla to fix so...
# 3   the service department is horrible in getting ...
# 4   the service center here is terrible i had a ti...
# 5   the service center here is terrible i had a ti...
# 6   unfortunately as a recent new tesla owner i ha...
# 7   my tesla 2016 model x would be the perfect car...
# 8   i had an issue with the undercarriage cover th...
# 9   we dropped our car at our scheduled appointmen...
# 10  there is inconsistency of excellent service he...
#
#                                  review_nopunc_nostop  \
# 0   today delivery day pretty excited collect car ...
# 1   terrible customer services guy name ck front i...
# 2   recently brought brand new tesla fix post deli...
# 3   service department horrible getting loaner car...
# 4   service center terrible tire needed patched ta...
# 5   service center terrible tire needed patched ta...
# 6   unfortunately recent new tesla owner agree maj...
# 7   tesla 2016 model x would perfect car ifservice...
# 8   issue undercarriage cover rep daniel manager r...
# 9   dropped car scheduled appointment 11am told ba...
# 10  inconsistency excellent service super duper ha...
#
#                         review_nopunc_nostop_nocommon  \
# 0   today delivery pretty excited collect car arri...
# 1   terrible customer services guy name ck front i...
# 2   recently brought brand new tesla fix post deli...
# 3   service department horrible getting loaner car...
# 4   service center terrible tire needed patched ta...
# 5   service center terrible tire needed patched ta...
# 6   unfortunately recent new tesla owner agree maj...
# 7   tesla 2016 model perfect car ifservice techs k...
# 8   issue undercarriage cover rep daniel manager r...
# 9   dropped car scheduled appointment 11am basic c...
# 10  inconsistency excellent service super duper ha...
#
#                                        cleaned_review  polarity  subjectivity
# 0   today delivery pretty excited collect car arri...  0.291106      0.667274
# 1   terrible customer service guy name ck front id... -0.053247      0.475758
# 2   recently brought brand new tesla fix post deli...  0.036830      0.429604
# 3   service department horrible getting loaner car... -0.400000      0.662500
# 4   service center terrible tire needed patched ta...  0.007917      0.427381
# 5   service center terrible tire needed patched ta...  0.007540      0.426077
# 6   unfortunately recent new tesla owner agree maj...  0.050758      0.294886
# 7   tesla 2016 model perfect car ifservice tech kn...  0.250000      0.383333
# 8   issue undercarriage cover rep daniel manager r...  0.300000      0.600000
# 9   dropped car scheduled appointment 11am basic c... -0.020455      0.296861
# 10  inconsistency excellent service super duper ha...  0.451042      0.720833
